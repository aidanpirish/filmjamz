# %% [markdown]
# # Insert Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

movies = pd.read_csv("movies.csv")

movies
# Out:
#                                       company    country             director  \
# 0               Columbia Pictures Corporation        USA           Rob Reiner
# 1                          Paramount Pictures        USA          John Hughes
# 2                          Paramount Pictures        USA           Tony Scott
# 3      Twentieth Century Fox Film Corporation        USA        James Cameron
# 4                        Walt Disney Pictures        USA       Randal Kleiser
# 5                                     Hemdale         UK         Oliver Stone
# 6                      Henson Associates (HA)         UK           Jim Henson
# 7     De Laurentiis Entertainment Group (DEG)        USA          David Lynch
# 8                          Paramount Pictures        USA        Howard Deutch
# 9                        SLM Production Group        USA     David Cronenberg
# 10                              Rimfire Films  Australia         Peter Faiman
# ...

# %% [markdown]
# # Preprocessing

# %%
from scipy.stats.kde import gaussian_kde
def kde_plot(x):   
    kde = gaussian_kde(x)
    positions = np.linspace(x.min(), x.max())
    smoothed = kde(positions)
    plt.plot(positions, smoothed)
    
def kde_values(x):   
    kde = gaussian_kde(x)
    positions = np.linspace(x.min(), x.max())
    smoothed = kde(positions)
    return positions, smoothed

# %%
x=movies['score']
x=x.dropna()
kde_plot(x)
plt.title("Distribution of rating data")
plt.show()

# %%
x=movies['gross']
x=x.dropna()
kde_plot(x)
plt.title("Distribution of gross")
plt.show()

# %%
y=movies.iloc[:,0].fillna(movies.mean()).as_matrix()
x=movies.iloc[:,1:].fillna(movies.mean()).as_matrix()
print y.shape
print x.shape
# Out:
# (6820,)
# (6820, 12)

# %% [markdown]
# # Random Forrest

# %%
from sklearn.tree import DecisionTreeRegressor

classify = DecisionTreeRegressor() # You can adjust some paraments here.
classify.fit(x,y)

y_pred = classify.predict(x)
classif_rate = np.mean(y_pred.ravel() == y.ravel()) * 100
print("classif_rate for %s : %f " % ('DecisionTreeRegressor', classif_rate))
print classify.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d97ea5841a6b> in <module>()
#       2
#       3 classify = DecisionTreeRegressor() # You can adjust some paraments here.
# ----> 4 classify.fit(x,y)
#       5
#       6 y_pred = classify.predict(x)
#
# /Users/aidanirish/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1027             sample_weight=sample_weight,
#    1028             check_input=check_input,
# -> 1029             X_idx_sorted=X_idx_sorted)
#    1030         return self
#    1031
#
# /Users/aidanirish/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     120         random_state = check_random_state(self.random_state)
#     121         if check_input:
# ...
